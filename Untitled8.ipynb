# %%
import pandas as pd

# %%
df=pd.read_csv("doct.csv")

# %%
df
# Out:
#       business_code cust_number  ...    invoice_id isOpen
# 0              U001  0200769623  ...  1.930779e+09      1
# 1              U001  0140142846  ...  1.929675e+09      0
# 2              U001  0100052024  ...  1.928861e+09      0
# 3              U001  0200726979  ...  1.930716e+09      1
# 4              U001  0200744019  ...  1.930781e+09      1
# ...             ...         ...  ...           ...    ...
# 49995          U001   200769623  ...  1.929533e+09      0
# 49996          U001  0200519201  ...  1.930688e+09      1
# 49997          CA02  0140104440  ...  2.960612e+09      0
# 49998          U013      CC6530  ...  1.991826e+09      0
# 49999          CA02  0140104240  ...  2.960535e+09      0
#
# [50000 rows x 19 columns]

# %%
df.head()
# Out:
#   business_code cust_number  ...    invoice_id isOpen
# 0          U001  0200769623  ...  1.930779e+09      1
# 1          U001  0140142846  ...  1.929675e+09      0
# 2          U001  0100052024  ...  1.928861e+09      0
# 3          U001  0200726979  ...  1.930716e+09      1
# 4          U001  0200744019  ...  1.930781e+09      1
#
# [5 rows x 19 columns]

# %%
df['date_published']=pd.to_datetime(df['document_create_date']).dt.date
#df["delay"]=df["due_in_date"]-df["clear_date"]
df['date_published']
# Out:
# 0        1970-01-01
# 1        1970-01-01
# 2        1970-01-01
# 3        1970-01-01
# 4        1970-01-01
#             ...
# 49995    1970-01-01
# 49996    1970-01-01
# 49997    1970-01-01
# 49998    1970-01-01
# 49999    1970-01-01
# Name: date_published, Length: 50000, dtype: object

# %%
df[df["isOpen"]==1]["isOpen"].plot()

# %%
df
# Out:
#       business_code cust_number  ...    invoice_id isOpen
# 0              U001  0200769623  ...  1.930779e+09      1
# 1              U001  0140142846  ...  1.929675e+09      0
# 2              U001  0100052024  ...  1.928861e+09      0
# 3              U001  0200726979  ...  1.930716e+09      1
# 4              U001  0200744019  ...  1.930781e+09      1
# ...             ...         ...  ...           ...    ...
# 49995          U001   200769623  ...  1.929533e+09      0
# 49996          U001  0200519201  ...  1.930688e+09      1
# 49997          CA02  0140104440  ...  2.960612e+09      0
# 49998          U013      CC6530  ...  1.991826e+09      0
# 49999          CA02  0140104240  ...  2.960535e+09      0
#
# [50000 rows x 19 columns]

# %%
df.corr()
# Out:
#                         buisness_year    doc_id  ...  invoice_id    isOpen
# buisness_year                1.000000 -0.008605  ...   -0.006817  0.756264
# doc_id                      -0.008605  1.000000  ...    1.000000 -0.006195
# document_create_date         0.976747 -0.006022  ...   -0.003993  0.766486
# document_create_date.1       0.982697 -0.007836  ...   -0.005799  0.766061
# due_in_date                  0.989151 -0.010663  ...   -0.008657  0.756306
# posting_id                        NaN       NaN  ...         NaN       NaN
# area_business                     NaN       NaN  ...         NaN       NaN
# total_open_amount           -0.003647  0.177496  ...    0.186578  0.002195
# baseline_create_date         0.983189 -0.005495  ...   -0.003353  0.765788
# invoice_id                  -0.006817  1.000000  ...    1.000000 -0.004829
# isOpen                       0.756264 -0.006195  ...   -0.004829  1.000000
#
# [11 rows x 11 columns]

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
